# %% [markdown]
# ## Installation

# %%
# @title
import os
# !git clone https://github.com/VasuVerma990/Stable-Diffusion -q
# !wget https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.ckpt -O /content/Stable-Diffusion/data/v1-5-pruned-emaonly.ckpt -q
# !pip install lightning -q

# %% [markdown]
# ## Loading Model

# %%
# @title
import sys
sys.path.append('/content/Stable-Diffusion')

from sd import model_loader
from sd import pipeline

from PIL import Image
from transformers import CLIPTokenizer
import torch
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

DEVICE = "cpu"

ALLOW_CUDA = True
ALLOW_MPS = False

if torch.cuda.is_available() and ALLOW_CUDA:
    DEVICE = "cuda"
elif (torch.has_mps or torch.backends.mps.is_available()) and ALLOW_MPS:
    DEVICE = "mps"
print(f"Using device {DEVICE} ")

tokenizer = CLIPTokenizer("/content/Stable-Diffusion/data/vocab.json", merges_file = "/content/Stable-Diffusion/data/merges.txt")
model_file = "/content/Stable-Diffusion/data/v1-5-pruned-emaonly.ckpt"
models = model_loader.preload_models_from_standard_weights(model_file, DEVICE)

# %% [markdown]
# ## Inference

# %%
prompt = "A cat stretching on the floor"
uncond_prompt = " "
do_cfg = True
cfg_scale = 7

#IMAGE to IMAGE
input_image = None
image_path = ""
#input_image = Image.open(image_path)
strength = 0.9

sampler = "ddpm"
num_inference_steps = 50
seed = 42

output_image = pipeline.generate(
    prompt=prompt,
    uncond_prompt=uncond_prompt,
    input_image=input_image,
    strength=strength,
    do_cfg=do_cfg,
    cfg_scale=cfg_scale,
    sampler_name=sampler,
    n_inference_steps=num_inference_steps,
    seed=seed,
    models=models,
    device=DEVICE,
    idle_device="cpu",
    tokenizer=tokenizer
)

Image.fromarray(output_image)
